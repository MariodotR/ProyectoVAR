# %% [markdown]
# código de ventana

# %%
#name_image="offside1.png"
#name_image="offside2.png"
name_image="off side 3.png"

# %%
img = cv.imread(name_image)
hsv = cv.cvtColor(img, cv2.COLOR_BGR2RGB)
f, axarr = plt.subplots( figsize=(20,20)) 
axarr.imshow(img)
axarr.axis("off")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f2a1f3906fb4> in <module>
# ----> 1 img = cv.imread(name_image)
#       2 hsv = cv.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3 f, axarr = plt.subplots( figsize=(20,20))
#       4 axarr.imshow(img)
#       5 axarr.axis("off")
#
# NameError: name 'cv' is not defined

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Load image
image = cv2.imread(name_image)

# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    result = cv2.resize(result, (960, 540))
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 254)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 253)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 252)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 251)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 250)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 249)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 248)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 246)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 245)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 242)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 239)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 236)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 235)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 234)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 233)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 232)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 231)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 230)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 229)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 228)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 227)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 226)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 225)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 224)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 223)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 221)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 220)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 219)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 218)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 217)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 216)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 215)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 214)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 212)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 211)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 210)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 209)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 208)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 207)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 206)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 205)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 204)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 203)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 204)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 205)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 206)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 207)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 208)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 209)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 210)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 211)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 212)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 213)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 214)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 215)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 216)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 217)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 218)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 219)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 220)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 221)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 254, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 253, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 252, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 251, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 249, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 248, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 247, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 246, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 245, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 243, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 242, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 241, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 239, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 238, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 236, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 235, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 233, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 232, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 231, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 229, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 228, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 227, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 226, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 225, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 224, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 223, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 222, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 221, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 220, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 219, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 218, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 217, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 216, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 215, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 214, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 213, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 212, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 211, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 210, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 209, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 207, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 206, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 205, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 204, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 203, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 202, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 200, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 199, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 198, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 197, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 195, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 194, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 192, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 191, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 190, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 189, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 188, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 187, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 186, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 185, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 184, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 183, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 182, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 181, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 180, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 179, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 178, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 177, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 176, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 175, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 174, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 173, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 171, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 170, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 168, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 166, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 164, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 163, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 161, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 160, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 158, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 156, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 154, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 153, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 151, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 150, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 149, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 148, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 147, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 146, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 145, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 144, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 143, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 142, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 141, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 140, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 139, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 138, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 137, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 136, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 135, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 134, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 133, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 132, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 131, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 130, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 129, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 128, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 127, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 126, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 125, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 124, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 123, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 122, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 121, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 120, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 119, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 118, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 117, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 116, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 115, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 114, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 113, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 112, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 111, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 110, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 109, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 108, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 107, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 106, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 104, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 103, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 102, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 101, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 100, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 99, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 98, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 97, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 96, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 97, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 98, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 99, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 100, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 101, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 102, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 103, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 104, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 106, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 107, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 108, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 109, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 110, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 111, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 113, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 114, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 116, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 117, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 119, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 120, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 121, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 120, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 119, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 118, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 117, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 116, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 115, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 114, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 113, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 112, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 111, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 110, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 109, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 108, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 107, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 106, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 104, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 103, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 102, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 101, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 100, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 99, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 98, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 97, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 96, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 95, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 93, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 92, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 91, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 90, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 89, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 88, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 87, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 86, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 85, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 83, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 84, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 83, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 84, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 85, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 86, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 87, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 88, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 89, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 90, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 91, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 92, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 93, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 94, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 95, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 96, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 97, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 98, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 99, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 100, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 101, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 102, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 103, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 104, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 106, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 107, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 106, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 177 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 174 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 173 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 172 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 170 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 168 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 166 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 165 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 164 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 163 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 162 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 160 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 159 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 158 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 155 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 154 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 153 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 151 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 150 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 147 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 145 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 143 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 142 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 141 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 140 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 138 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 136 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 133 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 131 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 129 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 127 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 125 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 124 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 123 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 121 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 120 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 119 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 117 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 116 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 115 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 114 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 113 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 112 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 111 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 110 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 109 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 108 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 107 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 106 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 105 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 104 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 103 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 102 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 101 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 100 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 99 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 98 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 97 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 96 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 94 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 93 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 92 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 91 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 90 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 89 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 88 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 87 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 86 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 85 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 84 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 82 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 80 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 78 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 77 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 75 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 74 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 72 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 69 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 68 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 67 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 66 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 65 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 63 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 62 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 60 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 59 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 58 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 56 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 55 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 54 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 53 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 52 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 53 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 54 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 55 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 56 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 57 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 58 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 59 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 60 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 61 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 62 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 63 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 64 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 65 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 66 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 67 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 68 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 69 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 2), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 4), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 5), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 7), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 9), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 10), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 11), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 12), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 13), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 15), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 16), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 17), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 18), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 20), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 21), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 22), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 23), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 25), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 27), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 28), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 30), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 31), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 33), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 35), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 37), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 38), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 40), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 42), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 43), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 44), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 46), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 48), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 49), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 50), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 51), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 52), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 53), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 54), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 55), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 56), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 57), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 58), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 59), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 60), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 61), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 62), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 64), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 65), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 66), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 67), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 69), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 70), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 71), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 72), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 73), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 75), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 76), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 77), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 79), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 80), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 81), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 82), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 83), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 84), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 85), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 86), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 88), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 89), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 91), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 92), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 93), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 94), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 96), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 97), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 98), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 100), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 102), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 104), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 106), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 108), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 111), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 113), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 115), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 117), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 118), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 119), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 120), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 121), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 123), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 124), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 125), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 126), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 127), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 128), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 129), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 130), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 131), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 132), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 133), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 134), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 136), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 137), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 138), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 139), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 140), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 141), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 143), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 144), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 146), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 147), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 148), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 150), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 153), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 157), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 159), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 163), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 164), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 166), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 168), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 172), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 177), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 179), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 181), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 182), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 185), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 187), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 188), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 189), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 187), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 185), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 183), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 181), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 179), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 178), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 177), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 176), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 175), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 173), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 172), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 171), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 169), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 166), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 164), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 163), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 160), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 159), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 157), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 153), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 150), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 148), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 147), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 148), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 150), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 153), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 157), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 159), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 160), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 164), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 167), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 168), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 171), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 172), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 173), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 175), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 174), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 170), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 165), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 162), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 161), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 159), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 158), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 150), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 148), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 147), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 146), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 144), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 143), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 141), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 140), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 139), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 138), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 137), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 136), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 134), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 133), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 132), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 131), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 130), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 131), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 133), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 135), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 137), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 138), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 139), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 140), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 141), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 142), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 143), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 144), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 145), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 146), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 147), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 149), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 150), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 151), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 152), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 155), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 0, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 2, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 4, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 6, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 8, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 10, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 12, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 13, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 15, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 17, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 19, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 20, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 21, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 22, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 23, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 24, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 25, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 26, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 27, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 28, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 29, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 30, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 32, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 33, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 34, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 36, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 37, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 38, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 39, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 40, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 41, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 42, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 43, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 44, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 45, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 44, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 43, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 42, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 41, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 40, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 39, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 38, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 37, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 36, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 35, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 34, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 33, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 32, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 0 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 1 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 2 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 3 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 4 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 5 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 6 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 7 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 8 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 9 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 10 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 12 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 13 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 14 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 15 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 16 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 17 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 19 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 20 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 21 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 23 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 24 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 25 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 26 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 27 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 28 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 29 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 30 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 31 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 32 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 33 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 34 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 35 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 36 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 37 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 38 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 39 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 40 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 41 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 42 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 43 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 44 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 45 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 46 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 47 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 48 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 47 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 46 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 45 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 44 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 43 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 42 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = 41 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
# (hMin = -1 , sMin = -1, vMin = -1), (hMax = -1 , sMax = -1, vMax = -1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2a924f02f5e0> in <module>
#      60     result = cv2.resize(result, (960, 540))
#      61     cv2.imshow('image', result)
# ---> 62     if cv2.waitKey(10) & 0xFF == ord('q'):
#      63         break
#      64
#
# KeyboardInterrupt:

# %% [markdown]
# # PASTO

# %%
#import the libraries
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#read the image
img = cv.imread(name_image)

# %%
#set the lower and upper bounds for the green hue
lower_green = np.array([37,92,87])
upper_green = np.array([44,255,255])
#2
#(hMin = 33 , sMin = 88, vMin = 104), (hMax = 44 , sMax = 148, vMax = 155)

lower_green = np.array([33,88,104])
upper_green = np.array([44,148,155])

#(hMin = 36 , sMin = 91, vMin = 67), (hMax = 47 , sMax = 172, vMax = 155)

lower_green = np.array([36,91,67])
upper_green = np.array([47,172,155])

#convert the BGR image to HSV colour space
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
#obtain the grayscale image of the original image
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)


#create a mask using the bounds set
mask = cv.inRange(hsv, lower_green, upper_green)
#create an inverse of the mask
mask_inv = cv.bitwise_not(mask)
#Filter only the red colour from the original image using the mask(foreground)
res = cv.bitwise_and(img, img, mask=mask)
#Filter the regions containing colours other than red from the grayscale image(background)
background = cv.bitwise_and(gray, gray, mask = mask_inv)
#convert the one channelled grayscale background to a three channelled image
background = np.stack((background,)*3, axis=-1)
#add the foreground and the background
added_img = cv.add(res, background)



    #subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(7,1,  figsize=(20,40)) 
axarr[0].imshow(background)
axarr[0].title.set_text("back")
axarr[0].axis("off")

axarr[1].imshow(mask_inv)
axarr[1].title.set_text("mask_inv")
axarr[1].axis("off")

axarr[2].imshow(added_img)
axarr[2].title.set_text("added_img")
axarr[2].axis("off")

axarr[3].imshow(mask)
axarr[3].title.set_text("mask")
axarr[3].axis("off")

axarr[4].imshow(gray)
axarr[4].title.set_text("gray")
axarr[4].axis("off")

axarr[5].imshow(hsv)
axarr[5].title.set_text("hsv")
axarr[5].axis("off")

axarr[6].imshow(res)
axarr[6].title.set_text("res")
axarr[6].axis("off")
# Out:
# (-0.5, 2609.5, 1339.5, -0.5)

# %%
f, axarr = plt.subplots( figsize=(20,20)) 
axarr.imshow(res)
#axarr.title.set_text("Filtro de Césped: off side 1")
axarr.axis("off")
# Out:
# (-0.5, 2609.5, 1339.5, -0.5)

# %% [markdown]
# # lineas del campo

# %%
#set the lower and upper bounds for the green hue
lower_white = np.array([44,23,138])
upper_white = np.array([101,107,229])



#(hMin = 41 , sMin = 31, vMin = 156), (hMax = 70 , sMax = 105, vMax = 222)
lower_white = np.array([41,31,156])
upper_white = np.array([70,105,222])
#import the libraries
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
#convert the BGR image to HSV colour space
img = cv.imread(name_image)
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
#obtain the grayscale image of the original image
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)


#create a mask using the bounds set
mask = cv.inRange(hsv, lower_white, upper_white)
#create an inverse of the mask
mask_inv = cv.bitwise_not(mask)
#Filter only the red colour from the original image using the mask(foreground)
res = cv.bitwise_and(img, img, mask=mask)
#Filter the regions containing colours other than red from the grayscale image(background)
background = cv.bitwise_and(gray, gray, mask = mask_inv)
#convert the one channelled grayscale background to a three channelled image
background = np.stack((background,)*3, axis=-1)
#add the foreground and the background
added_img = cv.add(res, background)



    #subplot(r,c) provide the no. of rows and columns
f, axarr = plt.subplots(7,1,  figsize=(20,40)) 
axarr[0].imshow(background)
axarr[0].title.set_text("back")
axarr[0].axis("off")

axarr[1].imshow(mask_inv)
axarr[1].title.set_text("mask_inv")
axarr[1].axis("off")

axarr[2].imshow(added_img)
axarr[2].title.set_text("added_img")
axarr[2].axis("off")

axarr[3].imshow(mask)
axarr[3].title.set_text("mask")
axarr[3].axis("off")

axarr[4].imshow(gray)
axarr[4].title.set_text("gray")
axarr[4].axis("off")

axarr[5].imshow(hsv)
axarr[5].title.set_text("hsv")
axarr[5].axis("off")

axarr[6].imshow(res)
axarr[6].title.set_text("res")
axarr[6].axis("off")
# Out:
# (-0.5, 2609.5, 1339.5, -0.5)

# %%
f, axarr = plt.subplots( figsize=(20,20)) 
axarr.imshow(res)
#axarr.title.set_text("Filtro de Césped: off side 1")
axarr.axis("off")
# Out:
# (-0.5, 2609.5, 1339.5, -0.5)

# %% [markdown]
# # LINEAS

# %%
"""
@file morph_lines_detection.py
@brief Use morphology transformations for extracting horizontal and vertical lines sample code
"""
import numpy as np
import sys
import cv2 as cv
def show_wait_destroy(winname, img):
    cv.imshow(winname, img)
    cv.moveWindow(winname, 500, 0)
    cv.waitKey(0)
    cv.destroyWindow(winname)
def main(argv):
    # [load_image]
    # Check number of arguments
    if len(argv) < 1:
        print ('Not enough parameters')
        print ('Usage:\nmorph_lines_detection.py < path_to_image >')
        return -1
    # Load the image
    #src = cv.imread(argv[0], cv.IMREAD_COLOR)
    src= res
    # Check if image is loaded fine
    if src is None:
        print ('Error opening image: ' + argv[0])
        return -1
    # Show source image
    cv.imshow("src", src)
    # [load_image]
    # [gray]
    # Transform source image to gray if it is not already
    if len(src.shape) != 2:
        gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
    else:
        gray = src
    # Show gray image
    #show_wait_destroy("gray", gray)
    # [gray]
    # [bin]
    # Apply adaptiveThreshold at the bitwise_not of gray, notice the ~ symbol
    gray = cv.bitwise_not(gray)
    bw = cv.adaptiveThreshold(gray, 255, cv.ADAPTIVE_THRESH_MEAN_C, \
                                cv.THRESH_BINARY, 15, -2)
    # Show binary image
    #bueno
    show_wait_destroy("binary", bw)
    
    
    
    
    
    
    
    # [bin]
    # [init]
    # Create the images that will use to extract the horizontal and vertical lines
    horizontal = np.copy(bw)
    vertical = np.copy(bw)
    # [init]
    # [horiz]
    # Specify size on horizontal axis
    cols = horizontal.shape[1]
    horizontal_size = cols // 30
    # Create structure element for extracting horizontal lines through morphology operations
    horizontalStructure = cv.getStructuringElement(cv.MORPH_RECT, (horizontal_size, 1))
    # Apply morphology operations
    horizontal = cv.erode(horizontal, horizontalStructure)
    horizontal = cv.dilate(horizontal, horizontalStructure)
    # Show extracted horizontal lines
   # show_wait_destroy("horizontal", horizontal)
    # [horiz]
    # [vert]
    # Specify size on vertical axis
    rows = vertical.shape[0]
    verticalsize = rows // 30
    # Create structure element for extracting vertical lines through morphology operations
    verticalStructure = cv.getStructuringElement(cv.MORPH_RECT, (1, verticalsize))
    # Apply morphology operations
    vertical = cv.erode(vertical, verticalStructure)
    vertical = cv.dilate(vertical, verticalStructure)
    # Show extracted vertical lines
    #show_wait_destroy("vertical", vertical)
    # [vert]
    # [smooth]
    # Inverse vertical image
    vertical = cv.bitwise_not(vertical)
   # show_wait_destroy("vertical_bit", vertical)
    '''
    Extract edges and smooth image according to the logic
    1. extract edges
    2. dilate(edges)
    3. src.copyTo(smooth)
    4. blur smooth img
    5. smooth.copyTo(src, edges)
    '''
    # Step 1
    edges = cv.adaptiveThreshold(vertical, 255, cv.ADAPTIVE_THRESH_MEAN_C, \
                                cv.THRESH_BINARY, 3, -2)
    show_wait_destroy("edges", edges)
    # Step 2
    kernel = np.ones((2, 2), np.uint8)
    edges = cv.dilate(edges, kernel)
    show_wait_destroy("dilate", edges)
    # Step 3
    smooth = np.copy(vertical)
    # Step 4
    smooth = cv.blur(smooth, (2, 2))
    # Step 5
    (rows, cols) = np.where(edges != 0)
    vertical[rows, cols] = smooth[rows, cols]
    # Show final result
    show_wait_destroy("smooth - final", vertical)
    # [smooth]
    return 0
if __name__ == "__main__":
    main(["offside1.png"])

# %% [markdown]
# # CONTORNO

# %% [markdown]
# https://docs.opencv.org/4.x/df/d0d/tutorial_find_contours.html

# %%
from __future__ import print_function
import cv2 as cv
import numpy as np
import argparse
import random as rng
rng.seed(12345)
def thresh_callback(val):
    threshold = val
    # Detect edges using Canny
    canny_output = cv.Canny(src_gray, threshold, threshold * 2)
    # Find contours
    contours, hierarchy = cv.findContours(canny_output, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    # Draw contours
    drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
    for i in range(len(contours)):
        color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        cv.drawContours(drawing, contours, i, color, 2, cv.LINE_8, hierarchy, 0)
    # Show in a window
    cv.imshow('Contours', drawing)

src = cv.imread(cv.samples.findFile('offside1.png'))
src= res
# Convert image to gray and blur it
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
src_gray = cv.blur(src_gray, (3,3))
# Create Window
source_window = 'Source'
cv.namedWindow(source_window)
cv.imshow(source_window, src)
max_thresh = 255
thresh = 100 # initial threshold
cv.createTrackbar('Canny Thresh:', source_window, thresh, max_thresh, thresh_callback)
thresh_callback(thresh)
cv.waitKey()
# Out:
# -1

# %% [markdown]
#  # ENVOLTURA CONVEXA

# %% [markdown]
# https://docs.opencv.org/4.x/d7/d1d/tutorial_hull.html

# %%
from __future__ import print_function
import cv2 as cv
import numpy as np
import argparse
import random as rng
rng.seed(12345)
def thresh_callback(val):
    threshold = val
    # Detect edges using Canny
    canny_output = cv.Canny(src_gray, threshold, threshold * 2)
    # Find contours
    contours, _ = cv.findContours(canny_output, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    # Find the convex hull object for each contour
    hull_list = []
    for i in range(len(contours)):
        hull = cv.convexHull(contours[i])
        hull_list.append(hull)
    # Draw contours + hull results
    drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
    for i in range(len(contours)):
        color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        cv.drawContours(drawing, contours, i, color)
        cv.drawContours(drawing, hull_list, i, color)
    # Show in a window
    cv.imshow('Contours', drawing)

src = cv.imread(cv.samples.findFile('offside1.png'))
src=res
# Convert image to gray and blur it
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
src_gray = cv.blur(src_gray, (3,3))
# Create Window
source_window = 'Source'
cv.namedWindow(source_window)
cv.imshow(source_window, src)
max_thresh = 255
thresh = 100 # initial threshold
cv.createTrackbar('Canny thresh:', source_window, thresh, max_thresh, thresh_callback)
thresh_callback(thresh)
cv.waitKey()
# Out:
# -1

# %% [markdown]
# # Hough line transform

# %% [markdown]
# https://docs.opencv.org/4.x/d9/db0/tutorial_hough_lines.html

# %%
"""
@file hough_lines.py
@brief This program demonstrates line finding with the Hough transform
"""
import sys
import math
import cv2 as cv
import numpy as np
def main(argv):
    
    #filename = argv[0] if len(argv) > 0 else default_file
    # Loads an image
    src = cv.imread(cv.samples.findFile(name_image), cv.IMREAD_GRAYSCALE)
    src=res
    # Check if image is loaded fine
    if src is None:
        print ('Error opening image!')
        print ('Usage: hough_lines.py [image_name -- default ' + default_file + '] \n')
        return -1
    
    
    dst = cv.Canny(src, 50, 200, None, 3)
    
    # Copy edges to the images that will display the results in BGR
    cdst = cv.cvtColor(dst, cv.COLOR_GRAY2BGR)
    cdstP = np.copy(cdst)
    
    lines = cv.HoughLines(dst, 1, np.pi / 180, 150, None, 0, 0)
    
    if lines is not None:
        for i in range(0, len(lines)):
            rho = lines[i][0][0]
            theta = lines[i][0][1]
            a = math.cos(theta)
            b = math.sin(theta)
            x0 = a * rho
            y0 = b * rho
            pt1 = (int(x0 + 10*(-b)), int(y0 + 10*(a)))
            pt2 = (int(x0 - 10*(-b)), int(y0 - 10*(a)))
            cv.line(cdst, pt1, pt2, (0,0,255), 3, cv.LINE_AA)
    
    
    linesP = cv.HoughLinesP(dst, 1, np.pi / 180, 50, None, 50, 10)
    
    if linesP is not None:
        for i in range(0, len(linesP)):
            l = linesP[i][0]
            cv.line(cdstP, (l[0], l[1]), (l[2], l[3]), (0,0,255), 3, cv.LINE_AA)
    
    cv.imshow("Source", src)
    cv.imshow("Detected Lines (in red) - Standard Hough Line Transform", cdst)
    cv.imshow("Detected Lines (in red) - Probabilistic Line Transform", cdstP)
    
    cv.waitKey()
    return 0
    
if __name__ == "__main__":
    main(sys.argv[1:])

# %% [markdown]
# # Laplace operator

# %% [markdown]
# https://docs.opencv.org/4.x/d5/db5/tutorial_laplace_operator.html

# %%
"""
@file laplace_demo.py
@brief Sample code showing how to detect edges using the Laplace operator
"""
import sys
import cv2 as cv
def main(argv):
    # [variables]
    # Declare the variables we are going to use
    ddepth = cv.CV_16S
    kernel_size = 3
    window_name = "Laplace Demo"
    # [variables]
    # [load]
    argv[0]= name_image
    imageName = argv[0] if len(argv) > 0 else 'lena.jpg'
    src = cv.imread(cv.samples.findFile(imageName), cv.IMREAD_COLOR) # Load an image
    src= res
    # Check if image is loaded fine
    if src is None:
        print ('Error opening image')
        print ('Program Arguments: [image_name -- default lena.jpg]')
        return -1
    # [load]
    # [reduce_noise]
    # Remove noise by blurring with a Gaussian filter
    src = cv.GaussianBlur(src, (3, 3), 0)
    # [reduce_noise]
    # [convert_to_gray]
    # Convert the image to grayscale
    src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
    # [convert_to_gray]
    # Create Window
    cv.namedWindow(window_name, cv.WINDOW_AUTOSIZE)
    # [laplacian]
    # Apply Laplace function
    dst = cv.Laplacian(src_gray, ddepth, ksize=kernel_size)
    # [laplacian]
    # [convert]
    # converting back to uint8
    abs_dst = cv.convertScaleAbs(dst)
    # [convert]
    # [display]
    cv.imshow(window_name, abs_dst)
    cv.waitKey(0)
    # [display]
    return 0
if __name__ == "__main__":
    main(sys.argv[1:])

# %% [markdown]
# # sobel

# %% [markdown]
# https://docs.opencv.org/4.x/d2/d2c/tutorial_sobel_derivatives.html

# %%
"""
@file sobel_demo.py
@brief Sample code using Sobel and/or Scharr OpenCV functions to make a simple Edge Detector
"""
import sys
import cv2 as cv
def main(argv):
    argv[0]= name_image
    window_name = ('Sobel Demo - Simple Edge Detector')
    scale = 1
    delta = 0
    ddepth = cv.CV_16S
    
    
    if len(argv) < 1:
        print ('Not enough parameters')
        print ('Usage:\nmorph_lines_detection.py < path_to_image >')
        return -1
    # Load the image
    src = cv.imread(argv[0], cv.IMREAD_COLOR)
    src= res
    # Check if image is loaded fine
    if src is None:
        print ('Error opening image: ' + argv[0])
        return -1
    
    
    src = cv.GaussianBlur(src, (3, 3), 0)
    
    
    gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
    
    
    grad_x = cv.Sobel(gray, ddepth, 1, 0, ksize=3, scale=scale, delta=delta, borderType=cv.BORDER_DEFAULT)
    # Gradient-Y
    # grad_y = cv.Scharr(gray,ddepth,0,1)
    grad_y = cv.Sobel(gray, ddepth, 0, 1, ksize=3, scale=scale, delta=delta, borderType=cv.BORDER_DEFAULT)
    
    
    abs_grad_x = cv.convertScaleAbs(grad_x)
    abs_grad_y = cv.convertScaleAbs(grad_y)
    
    
    grad = cv.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)
    
    
    cv.imshow(window_name, grad)
    cv.waitKey(0)
    
    return 0
if __name__ == "__main__":
    main(sys.argv[1:])

# %% [markdown]
# https://stackoverflow.com/questions/65065447/how-to-detect-lines-in-a-football-field-using-opencv

# %%
import cv2
from matplotlib import pyplot as plt
import numpy

im = cv2.imread(name_image)
B = im[:,:,2]
Y = 255-B

thresh = cv2.adaptiveThreshold(Y,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
cv2.THRESH_BINARY_INV,15,16)

contours, hierarchy = cv2.findContours(thresh,  
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE) 

x=[]
for i in range(0, len(contours)):
    if cv2.contourArea(contours[i]) > 200:
        x.append(contours[i])
cv2.drawContours(im, x, -1, (255,0,0), 2) 

plt.imshow(im)
